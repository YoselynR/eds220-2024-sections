# %%
import pandas as pd

# %%
# Access metadata from repository
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')

# %%
# Sets max column to none
pd.set_option("display.max.columns", None)

# %%
prey
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %%
type(prey)
# Out:
# pandas.core.frame.DataFrame

# %%
prey.head()
# Out:
#   attribute                            description
# 0     class   taxonomic class of observed organism
# 1     order   taxonomic order of observed organism
# 2    family  taxonomic family of observed organism
# 3     genus                             genus name
# 4   species               full latin binomial name

# %%
prey.tail()
# Out:
#    attribute                                        description
# 35      dist  distance to the nearest major road (kilometers...
# 36  dem90_hf  elevation (meters); data from the National Ele...
# 37  lc_class  landcover classification from the University o...
# 38      ndvi  the mean normalized difference vegetation inde...
# 39     notes  all bioX variables are from the WorldClim data...

# %%
prey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   attribute    40 non-null     object
#  1   description  40 non-null     object
# dtypes: object(2)
# memory usage: 768.0+ bytes

# %%
prey.nunique()
# Out:
# attribute      40
# description    40
# dtype: int64

# %%
prey.shape
# Out:
# (40, 2)

# %%
prey.columns
# Out:
# Index(['attribute', 'description'], dtype='object')

# %%
prey.dtypes
# Out:
# attribute      object
# description    object
# dtype: object

# %%
prey = prey.rename(index={'institutionCode': 'institution_code', 'datasetKey': 'dataset_key'})

# %%
prey
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...
